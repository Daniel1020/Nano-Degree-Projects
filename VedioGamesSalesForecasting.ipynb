# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel1020/Nano-Degree-Projects/blob/master/VedioGamesSalesForecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import statsmodels as stat
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
from statsmodels.tsa.seasonal import seasonal_decompose

# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a87010ac-899d-4b84-99a0-b7bf1f53ce44" name="files[]" multiple disabled />
#      <output id="result-a87010ac-899d-4b84-99a0-b7bf1f53ce44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving monthly-sales.csv to monthly-sales.csv

# %%
dat = pd.read_csv(io.BytesIO(uploaded['monthly-sales.csv']))
dat['Month']=pd.to_datetime(dat['Month'])

# %%
df= dat.copy()
df['Month']=pd.to_datetime(df['Month'])

# %%
df['year'] = df['Month'].apply(lambda x: x.year)
df['month']=df['Month'].apply(lambda x: x.month)

# %%
year_grp = df.groupby('year').agg({
    'Monthly Sales': lambda x: x.mean()
})

# %%
plt.plot(year_grp)

# %%
ax,fig = plt.subplots(figsize=(12,10))

sns.barplot(x='Month',y='Monthly Sales',data=df)

# %%
month_grp = df.groupby('month').agg({
    'Monthly Sales':lambda x:x.mean()
})

# %%
plt.plot(month_grp)

# %%
dat.plot()
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-5edf632c9704> in <module>()
#       1 dat.plot()
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9
result = seasonal_decompose(dat, model='multiplicative')
result.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-454bf2a0bd4a> in <module>()
#       3 result = seasonal_decompose(dat, model='multiplicative')
#       4 result.plot()
# ----> 5 pyplot.show()
#
# NameError: name 'pyplot' is not defined

# %% [markdown]
# We can see that the trend and seasonality information extracted from the series does seem reasonable. The residuals are also interesting, showing periods of high variability in the early and later years of the series.
